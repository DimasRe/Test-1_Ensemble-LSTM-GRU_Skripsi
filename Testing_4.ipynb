# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping

# %%
df = pd.read_csv("/content/drive/MyDrive/Skripsi/Dataset/data_bersih_GPR.csv")

df['DATE'] = pd.to_datetime(df['DATE'])

# SORT BERDASARKAN WAKTU
df = df.sort_values('DATE').reset_index(drop=True)

print("Jumlah data awal:", len(df))
# Out:
# Jumlah data awal: 10569

# %%
df['silver_return'] = df['SILVER_PRICE'].pct_change()
df['gold_return']   = df['GOLD_PRICE'].pct_change()

# Hapus hanya baris pertama (karena pct_change)
df = df.iloc[1:].reset_index(drop=True)

print("Jumlah data setelah return:", len(df))
# Out:
# Jumlah data setelah return: 10568
# /tmp/ipython-input-1952581561.py:1: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df['silver_return'] = df['SILVER_PRICE'].pct_change()

# %%
features = ['gold_return','silver_return','GPRD']
data = df[features].values

# %%
train_size = int(len(data) * 0.8)

train_data = data[:train_size]
test_data  = data[train_size:]

# %%
scaler = MinMaxScaler()

train_scaled = scaler.fit_transform(train_data)
test_scaled  = scaler.transform(test_data)

data_scaled = np.vstack((train_scaled, test_scaled))

# %%
def create_dataset(dataset, time_step):
    X, y = [], []
    for i in range(len(dataset)-time_step-1):
        X.append(dataset[i:(i+time_step), :])
        y.append(dataset[i+time_step, 1])
    return np.array(X), np.array(y)

time_step = 20

X, y = create_dataset(data_scaled, time_step)

print("Shape X:", X.shape)
print("Shape y:", y.shape)
# Out:
# Shape X: (10547, 20, 3)
# Shape y: (10547,)

# %%
train_size_window = int(len(X) * 0.8)

X_train = X[:train_size_window]
X_test  = X[train_size_window:]

y_train = y[:train_size_window]
y_test  = y[train_size_window:]

print("Final X_train shape:", X_train.shape)
# Out:
# Final X_train shape: (8437, 20, 3)

# %% [markdown]
# #LSTM

# %%
model_lstm = Sequential([
    Input(shape=(time_step, 3)),
    LSTM(64),
    Dropout(0.2),
    Dense(1)
])

model_lstm.compile(optimizer='adam', loss='mse')

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

history_lstm = model_lstm.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0182 - val_loss: 0.0026
# Epoch 2/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0043 - val_loss: 0.0027
# Epoch 3/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0041 - val_loss: 0.0032
# Epoch 4/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0039 - val_loss: 0.0027
# Epoch 5/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0036 - val_loss: 0.0025
# Epoch 6/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0034 - val_loss: 0.0025
# Epoch 7/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0033 - val_loss: 0.0025
# Epoch 8/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0034 - val_loss: 0.0025
# Epoch 9/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0031 - val_loss: 0.0025
# Epoch 10/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0030 - val_loss: 0.0025
# Epoch 11/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 12/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 13/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0029 - val_loss: 0.0025
# Epoch 14/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 15/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 16/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 17/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 18/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 19/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 20/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0027 - val_loss: 0.0024
# Epoch 21/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 22/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 23/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 24/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 25/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 26/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 27/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 28/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 29/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 30/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 31/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 32/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 33/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 34/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 35/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 36/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 37/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 38/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 39/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 40/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 41/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 42/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 43/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 44/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 45/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 46/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 47/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 48/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0027 - val_loss: 0.0024
# Epoch 49/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 50/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 51/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 52/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 53/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 54/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 55/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 56/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 57/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 58/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 59/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 60/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 61/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 62/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 63/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 64/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 65/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 66/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 67/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 68/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 69/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 70/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0025 - val_loss: 0.0024

# %% [markdown]
# #GRU

# %%
model_gru = Sequential([
    Input(shape=(time_step, 3)),
    GRU(64),
    Dropout(0.2),
    Dense(1)
])

model_gru.compile(optimizer='adam', loss='mse')

history_gru = model_gru.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.0651 - val_loss: 0.0026
# Epoch 2/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0048 - val_loss: 0.0026
# Epoch 3/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 0.0039 - val_loss: 0.0025
# Epoch 4/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0040 - val_loss: 0.0026
# Epoch 5/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0037 - val_loss: 0.0025
# Epoch 6/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0039 - val_loss: 0.0025
# Epoch 7/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0037 - val_loss: 0.0025
# Epoch 8/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 9/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 10/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0035 - val_loss: 0.0024
# Epoch 11/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0030 - val_loss: 0.0026
# Epoch 12/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0031 - val_loss: 0.0026
# Epoch 13/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 14/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0029 - val_loss: 0.0024
# Epoch 15/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 16/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 17/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 18/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 19/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0027 - val_loss: 0.0024
# Epoch 20/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 21/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 22/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 23/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 24/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 25/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 26/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0027 - val_loss: 0.0025

# %% [markdown]
# #Eval

# %%
pred_lstm = model_lstm.predict(X_test)
pred_gru  = model_gru.predict(X_test)
# Out:
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %%
def inverse_return(pred_scaled):
    dummy = np.zeros((len(pred_scaled), 3))
    dummy[:,1] = pred_scaled[:,0]
    inv = scaler.inverse_transform(dummy)
    return inv[:,1]

pred_lstm_inv = inverse_return(pred_lstm)
pred_gru_inv  = inverse_return(pred_gru)
y_test_inv    = inverse_return(y_test.reshape(-1,1))

# %%
rmse_lstm = np.sqrt(mean_squared_error(y_test_inv, pred_lstm_inv))
rmse_gru  = np.sqrt(mean_squared_error(y_test_inv, pred_gru_inv))

print("RMSE LSTM:", rmse_lstm)
print("RMSE GRU:", rmse_gru)
# Out:
# RMSE LSTM: 0.01738706880351662
# RMSE GRU: 0.017419129761058215

# %%
best_rmse = 999
best_alpha = 0

for alpha in np.arange(0,1.01,0.01):
    pred = alpha*pred_lstm_inv + (1-alpha)*pred_gru_inv
    rmse = np.sqrt(mean_squared_error(y_test_inv, pred))

    if rmse < best_rmse:
        best_rmse = rmse
        best_alpha = alpha

print("Best alpha:", best_alpha)
print("Best RMSE:", best_rmse)
# Out:
# Best alpha: 1.0
# Best RMSE: 0.01738706880351662
